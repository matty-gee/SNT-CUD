# %%
# import libraries
from social_place_general_utils import *
from social_place_encoding_utils import *
from social_place_decoding_utils import *
from social_place_plotting_utils import *

# %matplotlib inline

import os.path
import warnings
warnings.filterwarnings('ignore')
# Out:
# //anaconda3/lib/python3.7/site-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm
# //anaconda3/lib/python3.7/site-packages/nilearn/datasets/__init__.py:89: FutureWarning: Fetchers from the nilearn.datasets module will be updated in version 0.9 to return python strings instead of bytes and Pandas dataframes instead of Numpy arrays.
#   "Numpy arrays.", FutureWarning)

# %%
import collections
def get_quadrant(angle):
    angle = int(angle % 360.0) # ensure angle is from 0-360
    return int((angle/90) % 4 + 1)

# %% [markdown]
# # What subject level behaviors can we use to decode?

# %%
beh_df = pd.read_excel('/Volumes/synapse/projects/SocialSpace/Projects/Decoding_social_space/Behavior/Task_summary_n63.xlsx')

# %%
list(beh_df.columns)

# %%
# get quadrants for angles
var_list = ['allo2d.angles.values.end_mean','allo2d.angles.mean', 'allo2d.angles.uv.end', 'allo2d.angles.uv.mean', 'allo2d.angles.lw.end','allo2d.angles.lw.mean', 
            'ego2d.angles.mean','ego2d.angles.values.end_mean']
for angles in var_list:
    quadrants = [get_quadrant(angle) for angle in beh_df[angles]] 
    print(collections.Counter(quadrants))
    
# find a rotation that balances...?
# Out:
# Counter({2: 37, 1: 21, 3: 5})
# Counter({1: 29, 2: 16, 4: 11, 3: 7})
# Counter({1: 39, 2: 15, 4: 5, 3: 4})
# Counter({1: 31, 2: 17, 4: 9, 3: 6})
# Counter({2: 38, 1: 19, 3: 6})
# Counter({2: 44, 1: 11, 3: 8})
# Counter({1: 49, 2: 14})
# Counter({1: 52, 2: 11})

# %%
var_list = ['allo3d.volume', 'allo2d.area.end_coords', 'allo2d.area.all_coords', 'allo2d.consistency.mean','allo2d.dists.end_mean']
for var_ in var_list:
    sns.distplot(beh_df[var_])
    plt.show()

# %% [markdown]
# # Which of these differs between CDs & HCs?

# %%
# take stuff from prolific to examine...
