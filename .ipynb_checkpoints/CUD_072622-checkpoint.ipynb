# %% [markdown]
# 1. Categorical differences between CUD & HC
# 2. Continuous relationships within CUD to drug use patterns
# 3. Continuous relationships w/ childhood trauma

# %%
import sys, glob, os
import seaborn as sns
import matplotlib.pyplot as plt

from sklearn.preprocessing import OrdinalEncoder
import statsmodels.api as sm
import pandas as pd
import numpy as np
from statsmodels.formula.api import ols
from scipy.spatial import distance

main_dir = '/Users/matty_gee/Desktop/SNT/SNT-behavior'
sys.path.insert(0, main_dir + '/code')
from code_base import * 
sys.path.insert(0, main_dir + '/Online/Prolific/Code/0_utilities')
from prolific_generic_utils import *

task_details = pd.read_excel('task_details.xls')
character_roles = ['first', 'second', 'assistant', 'powerful', 'boss'] # order of matlab outputs...
pal = ["#14C8FF", "#FD25A7"] # blue, pink - for plotting colors

# %%
df = pd.read_excel(glob.glob('../All-data*')[0])
df = df[df['memory_mean'] > .2]
print(f'n={len(df)}')
sub_list = df['sub_id']
df['dx'].value_counts()
df = df.reset_index(drop=True)
# Out:
# n=68

# %%
list(df.columns)
# Out:
# ['dx',
#  'task_version',
#  'memory_mean',
#  'memory_1_powerful',
#  'memory_2_powerful',
#  'memory_3_boss',
#  'memory_4_neutral',
#  'memory_5_first',
#  'memory_6_assistant',
#  'memory_7_first',
#  'memory_8_second',
#  'memory_9_neutral',
#  'memory_10_powerful',
#  'memory_11_boss',
#  'memory_12_first',
#  'memory_13_neutral',
#  'memory_14_assistant',
#  'memory_15_assistant',
#  'memory_16_neutral',
#  'memory_17_second',
#  'memory_18_powerful',
#  'memory_19_assistant',
#  'memory_20_second',
#  'memory_21_neutral',
#  'memory_22_second',
#  'memory_23_powerful',
#  'memory_24_first',
#  'memory_25_boss',
#  'memory_26_first',
#  'memory_27_boss',
#  'memory_28_assistant',
#  'memory_29_second',
#  'memory_30_boss',
#  'rt_mean',
#  'missed_trials',
#  'sub_id',
#  'allo2d_perimeter',
#  'allo2d_area',
#  'allo3d_volume',
#  'quadrant_1_overlap',
#  'quadrant_2_overlap',
#  'quadrant_3_overlap',
#  'quadrant_4_overlap',
#  'rt_first',
#  'rt_affil_first',
#  'rt_power_first',
#  'affil_tendency_first',
#  'power_tendency_first',
#  'positive_tendency_first',
#  'affil_consistency_first',
#  'power_consistency_first',
#  'allo_dists_end_first',
#  'allo_dists_mean_first',
#  'allo2d_angles_end_first',
#  'allo2d_angles_mean_first',
#  'allo3d_angles_end_first',
#  'allo3d_angles_mean_first',
#  'allo_consistency_first',
#  'ego_dists_end_first',
#  'ego_dists_mean_first',
#  'ego2d_angles_end_first',
#  'ego2d_angles_mean_first',
#  'ego3d_angles_end_first',
#  'ego3d_angles_mean_first',
#  'rt_second',
#  'rt_affil_second',
#  'rt_power_second',
#  'affil_tendency_second',
#  'power_tendency_second',
#  'positive_tendency_second',
#  'affil_consistency_second',
#  'power_consistency_second',
#  'allo_dists_end_second',
#  'allo_dists_mean_second',
#  'allo2d_angles_end_second',
#  'allo2d_angles_mean_second',
#  'allo3d_angles_end_second',
#  'allo3d_angles_mean_second',
#  'allo_consistency_second',
#  'ego_dists_end_second',
#  'ego_dists_mean_second',
#  'ego2d_angles_end_second',
#  'ego2d_angles_mean_second',
#  'ego3d_angles_end_second',
#  'ego3d_angles_mean_second',
#  'rt_assistant',
#  'rt_affil_assistant',
#  'rt_power_assistant',
#  'affil_tendency_assistant',
#  'power_tendency_assistant',
#  'positive_tendency_assistant',
#  'affil_consistency_assistant',
#  'power_consistency_assistant',
#  'allo_dists_end_assistant',
#  'allo_dists_mean_assistant',
#  'allo2d_angles_end_assistant',
#  'allo2d_angles_mean_assistant',
#  'allo3d_angles_end_assistant',
#  'allo3d_angles_mean_assistant',
#  'allo_consistency_assistant',
#  'ego_dists_end_assistant',
#  'ego_dists_mean_assistant',
#  'ego2d_angles_end_assistant',
#  'ego2d_angles_mean_assistant',
#  'ego3d_angles_end_assistant',
#  'ego3d_angles_mean_assistant',
#  'rt_powerful',
#  'rt_affil_powerful',
#  'rt_power_powerful',
#  'affil_tendency_powerful',
#  'power_tendency_powerful',
#  'positive_tendency_powerful',
#  'affil_consistency_powerful',
#  'power_consistency_powerful',
#  'allo_dists_end_powerful',
#  'allo_dists_mean_powerful',
#  'allo2d_angles_end_powerful',
#  'allo2d_angles_mean_powerful',
#  'allo3d_angles_end_powerful',
#  'allo3d_angles_mean_powerful',
#  'allo_consistency_powerful',
#  'ego_dists_end_powerful',
#  'ego_dists_mean_powerful',
#  'ego2d_angles_end_powerful',
#  'ego2d_angles_mean_powerful',
#  'ego3d_angles_end_powerful',
#  'ego3d_angles_mean_powerful',
#  'rt_boss',
#  'rt_affil_boss',
#  'rt_power_boss',
#  'affil_tendency_boss',
#  'power_tendency_boss',
#  'positive_tendency_boss',
#  'affil_consistency_boss',
#  'power_consistency_boss',
#  'allo_dists_end_boss',
#  'allo_dists_mean_boss',
#  'allo2d_angles_end_boss',
#  'allo2d_angles_mean_boss',
#  'allo3d_angles_end_boss',
#  'allo3d_angles_mean_boss',
#  'allo_consistency_boss',
#  'ego_dists_end_boss',
#  'ego_dists_mean_boss',
#  'ego2d_angles_end_boss',
#  'ego2d_angles_mean_boss',
#  'ego3d_angles_end_boss',
#  'ego3d_angles_mean_boss',
#  'allo2d_angles_end_mean',
#  'allo2d_angles_mean_mean',
#  'ego2d_angles_end_mean',
#  'ego2d_angles_mean_mean',
#  'affil_tendency_mean',
#  'power_tendency_mean',
#  'positive_tendency_mean',
#  'affil_consistency_mean',
#  'power_consistency_mean',
#  'allo2d_angles_end_first_cos',
#  'allo2d_angles_end_first_sin',
#  'allo2d_angles_mean_first_cos',
#  'allo2d_angles_mean_first_sin',
#  'allo3d_angles_end_first_cos',
#  'allo3d_angles_end_first_sin',
#  'allo3d_angles_mean_first_cos',
#  'allo3d_angles_mean_first_sin',
#  'ego2d_angles_end_first_cos',
#  'ego2d_angles_end_first_sin',
#  'ego2d_angles_mean_first_cos',
#  'ego2d_angles_mean_first_sin',
#  'ego3d_angles_end_first_cos',
#  'ego3d_angles_end_first_sin',
#  'ego3d_angles_mean_first_cos',
#  'ego3d_angles_mean_first_sin',
#  'allo2d_angles_end_second_cos',
#  'allo2d_angles_end_second_sin',
#  'allo2d_angles_mean_second_cos',
#  'allo2d_angles_mean_second_sin',
#  'allo3d_angles_end_second_cos',
#  'allo3d_angles_end_second_sin',
#  'allo3d_angles_mean_second_cos',
#  'allo3d_angles_mean_second_sin',
#  'ego2d_angles_end_second_cos',
#  'ego2d_angles_end_second_sin',
#  'ego2d_angles_mean_second_cos',
#  'ego2d_angles_mean_second_sin',
#  'ego3d_angles_end_second_cos',
#  'ego3d_angles_end_second_sin',
#  'ego3d_angles_mean_second_cos',
#  'ego3d_angles_mean_second_sin',
#  'allo2d_angles_end_assistant_cos',
#  'allo2d_angles_end_assistant_sin',
#  'allo2d_angles_mean_assistant_cos',
#  'allo2d_angles_mean_assistant_sin',
#  'allo3d_angles_end_assistant_cos',
#  'allo3d_angles_end_assistant_sin',
#  'allo3d_angles_mean_assistant_cos',
#  'allo3d_angles_mean_assistant_sin',
#  'ego2d_angles_end_assistant_cos',
#  'ego2d_angles_end_assistant_sin',
#  'ego2d_angles_mean_assistant_cos',
#  'ego2d_angles_mean_assistant_sin',
#  'ego3d_angles_end_assistant_cos',
#  'ego3d_angles_end_assistant_sin',
#  'ego3d_angles_mean_assistant_cos',
#  'ego3d_angles_mean_assistant_sin',
#  'allo2d_angles_end_powerful_cos',
#  'allo2d_angles_end_powerful_sin',
#  'allo2d_angles_mean_powerful_cos',
#  'allo2d_angles_mean_powerful_sin',
#  'allo3d_angles_end_powerful_cos',
#  'allo3d_angles_end_powerful_sin',
#  'allo3d_angles_mean_powerful_cos',
#  'allo3d_angles_mean_powerful_sin',
#  'ego2d_angles_end_powerful_cos',
#  'ego2d_angles_end_powerful_sin',
#  'ego2d_angles_mean_powerful_cos',
#  'ego2d_angles_mean_powerful_sin',
#  'ego3d_angles_end_powerful_cos',
#  'ego3d_angles_end_powerful_sin',
#  'ego3d_angles_mean_powerful_cos',
#  'ego3d_angles_mean_powerful_sin',
#  'allo2d_angles_end_boss_cos',
#  'allo2d_angles_end_boss_sin',
#  'allo2d_angles_mean_boss_cos',
#  'allo2d_angles_mean_boss_sin',
#  'allo3d_angles_end_boss_cos',
#  'allo3d_angles_end_boss_sin',
#  'allo3d_angles_mean_boss_cos',
#  'allo3d_angles_mean_boss_sin',
#  'ego2d_angles_end_boss_cos',
#  'ego2d_angles_end_boss_sin',
#  'ego2d_angles_mean_boss_cos',
#  'ego2d_angles_mean_boss_sin',
#  'ego3d_angles_end_boss_cos',
#  'ego3d_angles_end_boss_sin',
#  'ego3d_angles_mean_boss_cos',
#  'ego3d_angles_mean_boss_sin',
#  'allo2d_angles_end_mean_cos',
#  'allo2d_angles_end_mean_sin',
#  'allo2d_angles_mean_mean_cos',
#  'allo2d_angles_mean_mean_sin',
#  'ego2d_angles_end_mean_cos',
#  'ego2d_angles_end_mean_sin',
#  'ego2d_angles_mean_mean_cos',
#  'ego2d_angles_mean_mean_sin',
#  'affil_consistency_mean_signed',
#  'power_consistency_mean_signed',
#  'allo_dists_end_mean',
#  'allo_dists_mean_mean',
#  'allo_consistency_mean',
#  'ego_dists_end_mean',
#  'ego_dists_mean_mean',
#  'decision_01',
#  'decision_02',
#  'decision_03',
#  'decision_04',
#  'decision_05',
#  'decision_06',
#  'decision_07',
#  'decision_08',
#  'decision_09',
#  'decision_10',
#  'decision_11',
#  'decision_12',
#  'decision_13',
#  'decision_14',
#  'decision_15',
#  'decision_16',
#  'decision_17',
#  'decision_18',
#  'decision_19',
#  'decision_20',
#  'decision_21',
#  'decision_22',
#  'decision_23',
#  'decision_24',
#  'decision_25',
#  'decision_26',
#  'decision_27',
#  'decision_28',
#  'decision_29',
#  'decision_30',
#  'decision_31',
#  'decision_32',
#  'decision_33',
#  'decision_34',
#  'decision_35',
#  'decision_36',
#  'decision_37',
#  'decision_38',
#  'decision_39',
#  'decision_40',
#  'decision_41',
#  'decision_42',
#  'decision_43',
#  'decision_44',
#  'decision_45',
#  'decision_46',
#  'decision_47',
#  'decision_48',
#  'decision_49',
#  'decision_50',
#  'decision_51',
#  'decision_52',
#  'decision_53',
#  'decision_54',
#  'decision_55',
#  'decision_56',
#  'decision_57',
#  'decision_58',
#  'decision_59',
#  'decision_60',
#  'decision_61',
#  'decision_62',
#  'decision_63',
#  'mentalizing_initial_screening_used_cocaine',
#  'mentalizing_initial_screening_drug_quit___coc',
#  'mentalizing_initial_screening_screen_coc_abs',
#  'mentalizing_initial_screening_cocaine_quit',
#  'mentalizing_initial_screening_current_tx_cocaine',
#  'screen_utox___coc',
#  'coc_hx',
#  'coc_last_use',
#  'coc_days_last_use',
#  'coc_lst_amount',
#  'coc_lst_money',
#  'coc_progression',
#  'coc_age_1st_use',
#  'coc_age_reg_use',
#  'coc_dur_years',
#  'coc_phu',
#  'coc_phu_patt',
#  'coc_phu_number',
#  'coc_phu_amount',
#  'coc_phu_money',
#  'coc_phu_duration',
#  'coc_cur_patt',
#  'coc_cur_number',
#  'coc_cur_amount',
#  'coc_cur_money',
#  'coc_cur_duration_years',
#  'coc_pastyr_patt',
#  'coc_pastyr_number',
#  'coc_pastyr_amount',
#  'coc_pastyr_money',
#  'coc_number_quit',
#  'coc_longest_abstinence',
#  'coc_inpt_tx',
#  'coc_outpt_tx',
#  'coc_detx_tx',
#  'coc_na_meetings',
#  'asi_coc_pastmonth',
#  'asi_coc_lifetime_years',
#  'asi_coc_roa1',
#  'asi_coc_roa2',
#  'cssa_4_coccrav',
#  'cssa_5_coccravfreq',
#  'stcq_screen_wantcoc_taste',
#  'stcq_screen_coc_urge',
#  'stcq_screen_use_coc_asap1',
#  'stcq_screen_resist_coc',
#  'stcq_screen_crave_coc',
#  'stcq_screen_alliwant_now_coc',
#  'stcq_screen_no_desire_coc',
#  'stcq_screen_cocuse_perfect',
#  'stcq_screen_use_coc_asap2',
#  'stcq_screen_nothing_better_usecoc',
#  'mri_utox___coc',
#  'stcq_mri_wantcoc_taste',
#  'stcq_mri_coc_urge',
#  'stcq_mri_use_coc_asap1',
#  'stcq_mri_resist_coc',
#  'stcq_mri_crave_coc',
#  'stcq_mri_alliwant_now_coc',
#  'stcq_mri_no_desire_coc',
#  'stcq_mri_cocuse_perfect',
#  'stcq_mri_use_coc_asap2',
#  'stcq_mri_nothing_better_usecoc',
#  'cssa_4_coccrav_mri',
#  'cssa_5_coccravfreq_mri',
#  'age_years',
#  'sex',
#  'ethnicity',
#  'race___white',
#  'race___aa',
#  'race___asian',
#  'race___hawaiin_pacific_island',
#  'race___american_indian',
#  'race___alaskan',
#  'race_revised___white',
#  'race_revised___aa',
#  'race_revised___asian',
#  'race_revised___hawaiin_pacific_island',
#  'race_revised___american_indian',
#  'race_revised___alaskan',
#  'race_revised___multiracial',
#  'mentalizing_initial_screening_edu_level',
#  'mentalizing_initial_screening_curr_emplmnt',
#  'mentalizing_initial_screening_curr_empl_status',
#  'mentalizing_initial_screening_curr_prfsn',
#  'mentalizing_initial_screening_curr_income',
#  'mentalizing_initial_screening_drink_alcohol',
#  'mentalizing_initial_screening_used_drugs',
#  'screen_breath_alc',
#  'screen_breath_co',
#  'screen_utox___thc',
#  'screen_utox___coc.1',
#  'screen_utox___amp',
#  'screen_utox___meth',
#  'screen_utox___opi',
#  'screen_utox___pcp',
#  'screen_utox___barb',
#  'screen_utox___bzo',
#  'screen_utox___methadone',
#  'screen_utox___oxy',
#  'screen_utox___mdma',
#  'screen_utox___tca',
#  'screen_utox___bup',
#  'screen_utox___neg',
#  'screen_height',
#  'screen_weight',
#  'wrat_age',
#  'wrat_version',
#  'wrat_blue_score',
#  'wrat_blue_score_total',
#  'wrat_tan_score',
#  'wrat_tan_total_score',
#  'wrat_t_score',
#  'wrat_grade_equiv',
#  'wrat_standard_score',
#  'colorcards_1_nrml_vision',
#  'colorcards_1_green_red_blindness',
#  'colorcards_2_total_blind',
#  'ehi_total_right',
#  'ehi_total_left',
#  'ehi_total_rl',
#  'ehi_total_ehi',
#  'staxi_state_anger_raw',
#  'staxi_s_anger_percentile',
#  'staxi_state_anger_tscore',
#  'staxi_state_feeling_angry_raw',
#  'staxi_feeling_angry_percent',
#  'staxi_feeling_angry_tscore',
#  'staxi_state_anger_verbally_raw',
#  'staxi_s_anger_verbally_percent',
#  'staxi_s_anger_verbally_tscore',
#  'staxi_state_anger_physically_raw',
#  'staxi_s_anger_physically_percent',
#  'staxi_s_anger_physically_tscore',
#  'staxi_trait_anger_raw',
#  'staxi_trait_anger_percent',
#  'staxi_trait_anger_tscore',
#  'staxi_trait_anger_temperament_raw',
#  'staxi_t_anger_temperament_percent',
#  'staxi_t_anger_temperament_tscore',
#  'staxi_trait_anger_reaction_raw',
#  'staxi_t_angry_reaction_percent',
#  'staxi_t_angry_reaction_tscore',
#  'staxi_anger_expressout_raw',
#  'staxi_angr_express_out_percent',
#  'staxi_angr_express_out_tscore',
#  'staxi_anger_exressin_raw',
#  'staxi_angr_express_in_percent',
#  'staxi_angr_express_in_tscore',
#  'staxi_anger_control_out_raw',
#  'staxi_angr_contrl_out_percent',
#  'staxi_angr_contrl_out_tscore',
#  'staxi_anger_controlin_raw',
#  'staxi_angr_contrl_in_percent',
#  'staxi_angr_contrl_in_tscore',
#  'staxi_anger_express_index',
#  'staxi_angr_express_index_percent',
#  'staxi_angr_express_index_tscore',
#  'bai_score',
#  'bdi_total',
#  'ctq_physical_abuse_score',
#  'ctq_emotional_abuse_score',
#  'ctq_sexual_abuse_score',
#  'ctq_emotional_neglect_score',
#  'ctq_physical_neglect_scale',
#  'ctq_minimization_score',
#  'ctq_total_score_2',
#  'alc_age_1st_use',
#  'alc_age_rgulr_use',
#  'alc_rgu_dur_years',
#  'opi_age_1st_use',
#  'opi_age_reg_use',
#  'opi_dur_years',
#  'barb_age_1st_use',
#  'barb_age_rgulr_use',
#  'barb_rgu_dur_years',
#  'sedative_age_1st_use',
#  'sedative_age_rgulr_use',
#  'sedative_rgu_dur_years',
#  'coc_age_1st_use.1',
#  'coc_age_reg_use.1',
#  'coc_dur_years.1',
#  'amp_age_1st_use',
#  'amp_age_reg_use',
#  'amp_dur_years',
#  'thc_age_1st_use',
#  'thc_age_reg_use',
#  'thc_duration_years',
#  'inh_age_1st_use',
#  'inh_age_reg_use',
#  'inh_dur_years',
#  'cssa_total',
#  'sds_total',
#  'matrix_t_score_updated',
#  'matrix_scaled_score_updated',
#  'ecrs_anxiety_subscale',
#  'ecrs_avoidance_subscale',
#  'ecrs_total',
#  'lsas_social_interaction_fear_subscale',
#  'lsas_performance_fear_subscale',
#  'lsas_social_interaction_avoidance_subscale',
#  'lsas_performance_avoidance_subscale',
#  'lsas_total_score',
#  'ders_strategies',
#  'ders_non_acceptance',
#  'ders_impulse',
#  'ders_goals',
#  'ders_awareness',
#  'ders_clarity',
#  'ders_total_score',
#  'agency_motivation_money_value',
#  'agency_motivation_social_value',
#  'agency_motivation_importance_group_inclusion',
#  'agency_motivation_money_drug_association',
#  'agency_motivation_money_social_association',
#  'isel_scr_appraisal_subscale',
#  'isel_scr_tangible_subscale',
#  'isel_scr_selfesteem_subscale',
#  'isel_scr_belonging_subscale',
#  'tas_difficulty_describing_feelings_subscale',
#  'tas_difficulty_identifying_feeling_subscale',
#  'tas_externally_oriented_thinking_subscale',
#  'tas_total',
#  'perceived_stress_scale_score',
#  'stai_statescore',
#  'stai_trait_total_score',
#  'sni_marital_status',
#  'sni_numbr_children',
#  'sni_numbr_children_contact',
#  'sni_parents_living',
#  'sni_parents_contact_biweekly',
#  'sni_inlaws',
#  'sni_in_laws_talk_biweekly',
#  'sni_other_relatives_close_to',
#  'sni_relatives_talk_to_biweekly',
#  'sni_num_close_friends',
#  'sni_friends_contact_biweekly',
#  'sni_religious_affiliation',
#  'sni_religious_affiliation_contact_biweekly',
#  'sni_attend_classes_regularly',
#  'sni_students_teachers_biweekly_contact',
#  'sni_employment_status',
#  'sni_ppl_supervise',
#  'sni_coworkers_biweekly_contact',
#  'sni_neighboors_biweekly_contact',
#  'sni_reg_volunteer_work',
#  'sni_volunteers_biweekly_contact',
#  'sni_other_volunteer_grp_member_biweekly_contact',
#  'sni_volunteer_grp_details',
#  'sni_total_nmbr_other_volunteers_biweekly_contact',
#  'sni_num_ppl',
#  'sni_network_div',
#  'first_gender',
#  'second_gender',
#  'assistant_gender',
#  'powerful_gender',
#  'boss_gender',
#  'neutral_gender',
#  'first_skincolor',
#  'second_skincolor',
#  'assistant_skincolor',
#  'powerful_skincolor',
#  'boss_skincolor',
#  'neutral_skincolor',
#  'dots_affil_second',
#  'dots_power_second',
#  'dots_affil_first',
#  'dots_power_first',
#  'dots_affil_powerful',
#  'dots_power_powerful',
#  'dots_affil_boss',
#  'dots_power_boss',
#  'dots_affil_neutral',
#  'dots_power_neutral',
#  'dots_affil_assistant',
#  'dots_power_assistant']

# %% [markdown]
# # Memory

# %%
sns.histplot(df[df['dx'] == 'HC']['memory_mean'], color='blue')
sns.histplot(df[df['dx'] == 'CD']['memory_mean'], color='red')

# %% [markdown]
# # Behavior

# %%
df['rt_affil_mean'] = np.mean(df[[c for c in df.columns if 'rt_affil' in c]],1)
df['rt_power_mean'] = np.mean(df[[c for c in df.columns if 'rt_power' in c]],1)

# %%
demo_controls = ['sex', 'age_years', 'race___white'] # , 'mentalizing_initial_screening_edu_level']
task_preds = ['affil_tendency_mean', 'power_tendency_mean',
              'ego2d_angles_end_mean', 'ego_dists_end_mean',
              'allo2d_angles_end_mean', 'allo_dists_end_mean',
              'allo_consistency_mean', 'allo2d_area', 'allo3d_volume',
              'rt_affil_mean', 'rt_power_mean']

# %% [markdown]
# ## Affil x Power coordinates

# %%
fig, axs = plt.subplots(2, 6, figsize=(20, 7), sharey=True)
fig.subplots_adjust(top=0.95)
fig.text(0.515, -0.02, 'Affiliation', ha='center', fontsize=20)
fig.text(0, 0.5, 'Power', va='center', rotation='vertical', fontsize=20)

for g, group in enumerate(np.unique(df['dx'])):
    df_ = df[df['dx'] == group]
    for c in range(0,6):
        if c == 5:
            sns.regplot(x='affil_tendency_mean',y='power_tendency_mean', data=df_, 
                        x_jitter=.25, y_jitter=.25, scatter_kws={'alpha':0.6}, color='darkblue',
                        ax=axs[g,c])
            axs[g,5].set_title('Mean', fontsize=20)
        else: 
            sns.regplot(x='affil_tendency_' + character_roles[c], 
                        y='power_tendency_' + character_roles[c], 
                        data=df_, 
                        x_jitter=.25, y_jitter=.25, scatter_kws={'alpha':0.6},
                        ax=axs[g,c])
            axs[g,c].set_title(character_roles[c].capitalize(), fontsize=20)
        axs[g,c].set_xlim(-1,1)
        axs[g,c].set_ylim(-1,1)
        axs[g,c].axhline(y=0, color='black')
        axs[g,c].axvline(x=0, color='black')
        axs[g,c].set_xlabel('')
        axs[g,c].set_ylabel('')
        
plt.tight_layout()
plt.show()
# jp.savefig(fig_dir + "/affil_power_correlation.png", dpi=150)

# %% [markdown]
# ## Other behavioral variables

# %% [markdown]
# ### ANOVAs & T-tests: CD v HC

# %%
task_preds_ = ['affil_tendency_mean', 'power_tendency_mean',
               'ego2d_angles_end_mean','ego_dists_end_mean',
               'allo2d_angles_end_mean','allo_consistency_mean','allo2d_area','allo3d_volume',
               'rt_affil_mean','rt_power_mean']
for var in task_preds:
    
    hc = df[df['dx'] == 'HC'][var]
    cd = df[df['dx'] == 'CD'][var]  
    
    if 'angles' in var:
        p,T = circ_wwtest(hc, cd)        
        if p < 0.05:
            if 'ego2d' in var:
                # for visualization
                hc = hc + 135
                cd = cd + 135

            print(var + ' p=' + str(np.round(p,5)))
            fig, ax = plt.subplots(figsize=(5,5), subplot_kw=dict(projection="polar"))
            n,bins,patches = circular_hist(ax, x=np.deg2rad(hc).values, color=pal[0]) # blue
            n,bins,patches = circular_hist(ax, x=np.deg2rad(cd).values, color=pal[1])  
            
    else:
        t,p = scipy.stats.ttest_ind(hc, cd)
        if p < 0.05:
            print(var + ' p=' + str(np.round(p,5)))
            sns.histplot(hc, color=pal[0]) # blue
            sns.histplot(cd, color=pal[1]) # pink
            plt.show()
# Out:
# //anaconda3/lib/python3.7/site-packages/pycircstat/tests.py:417: UserWarning: Test not applicable. Average resultant vector length < 0.45.
#   'Test not applicable. Average resultant vector length < 0.45.')
# allo2d_angles_end_mean p=0.01043

# %%
cd = df[df['dx'] == 'CD']
hc = df[df['dx'] == 'HC']
task_binedges = np.array([-1,-.6,-.2,.2,.6,1]) 
cd_h, _, _ = np.histogram2d(cd['affil_tendency_mean'], cd['power_tendency_mean'], bins=[task_binedges,task_binedges])
hc_h, _, _ = np.histogram2d(hc['affil_tendency_mean'], hc['power_tendency_mean'], bins=[task_binedges,task_binedges])
diff = cd_h.T - hc_h.T
plt.imshow(diff, interpolation=None, origin='lower',
            extent=[task_binedges[0], task_binedges[-1], task_binedges[0], task_binedges[-1]], cmap='RdBu')
plt.show()

# %%
sns.histplot(df[df['dx'] == 'HC']['allo2d_angles_end_mean'], color='blue')
sns.histplot(df[df['dx'] == 'CD']['allo2d_angles_end_mean'], color='red')
plt.show()

# %%
for pred in task_preds:
    if 'angles' not in pred:
        print(pred)
        long = pd.melt(df, id_vars=['sub_id', 'dx', 'sex', 'race___white', 'ctq_total_score_2'], 
                       value_vars=[pred])
        model = ols("value ~ C(sex, Sum) + C(race___white, Sum) + C(dx, Sum)", data=long).fit()
        aov_table = sm.stats.anova_lm(model, typ=3)
        display(aov_table)
# Out:
# affil_tendency_mean
#                         sum_sq    df         F    PR(>F)
# Intercept             0.315367   1.0  6.409447  0.013944
# C(sex, Sum)           0.039578   1.0  0.804381  0.373313
# C(race___white, Sum)  0.025952   1.0  0.527452  0.470458
# C(dx, Sum)            0.008824   1.0  0.179330  0.673439
# Residual              3.001408  61.0       NaN       NaN
# power_tendency_mean
#                         sum_sq    df          F        PR(>F)
# Intercept             3.794714   1.0  62.142677  6.991543e-11
# C(sex, Sum)           0.031072   1.0   0.508845  4.783597e-01
# C(race___white, Sum)  0.005473   1.0   0.089621  7.656768e-01
# C(dx, Sum)            0.089577   1.0   1.466928  2.305025e-01
# Residual              3.724937  61.0        NaN           NaN
# ego_dists_end_mean
#                            sum_sq    df            F        PR(>F)
# Intercept             2214.075848   1.0  1406.757151  7.691679e-44
# C(sex, Sum)              0.864014   1.0     0.548968  4.615822e-01
# C(race___white, Sum)     1.546650   1.0     0.982695  3.254505e-01
# C(dx, Sum)               0.220162   1.0     0.139884  7.096932e-01
# Residual                96.007066  61.0          NaN           NaN
# allo_dists_end_mean
#                           sum_sq    df            F        PR(>F)
# Intercept             694.952239   1.0  1140.358240  3.475287e-41
# C(sex, Sum)             0.007407   1.0     0.012154  9.125752e-01
# C(race___white, Sum)    1.812307   1.0     2.973843  8.968498e-02
# C(dx, Sum)              0.197252   1.0     0.323674  5.714967e-01
# Residual               37.174359  61.0          NaN           NaN
# allo_consistency_mean
#                         sum_sq    df            F        PR(>F)
# Intercept             8.301979   1.0  1023.894831  7.814274e-40
# C(sex, Sum)           0.011728   1.0     1.446427  2.337496e-01
# C(race___white, Sum)  0.030810   1.0     3.799851  5.585896e-02
# C(dx, Sum)            0.005228   1.0     0.644754  4.251122e-01
# Residual              0.494602  61.0          NaN           NaN
# allo2d_area
#                             sum_sq    df           F        PR(>F)
# Intercept             61954.249534   1.0  738.546933  8.709231e-36
# C(sex, Sum)              22.134522   1.0    0.263862  6.093348e-01
# C(race___white, Sum)     85.668397   1.0    1.021240  3.162170e-01
# C(dx, Sum)               24.629559   1.0    0.293605  5.898934e-01
# Residual               5117.087425  61.0         NaN           NaN
# allo3d_volume
#                             sum_sq    df           F        PR(>F)
# Intercept             1.941275e+06   1.0  756.712271  4.385514e-36
# C(sex, Sum)           2.128903e+02   1.0    0.082985  7.742688e-01
# C(race___white, Sum)  2.633731e+03   1.0    1.026633  3.149530e-01
# C(dx, Sum)            2.136981e+00   1.0    0.000833  9.770691e-01
# Residual              1.564898e+05  61.0         NaN           NaN
# rt_affil_mean
#                            sum_sq    df           F        PR(>F)
# Intercept             1212.174559   1.0  633.068626  6.555347e-34
# C(sex, Sum)              0.137666   1.0    0.071897  7.894989e-01
# C(race___white, Sum)     5.561287   1.0    2.904430  9.342571e-02
# C(dx, Sum)               2.867294   1.0    1.497469  2.257670e-01
# Residual               116.800367  61.0         NaN           NaN
# rt_power_mean
#                            sum_sq    df           F        PR(>F)
# Intercept             1047.021913   1.0  619.840046  1.180013e-33
# C(sex, Sum)              0.417691   1.0    0.247274  6.207887e-01
# C(race___white, Sum)     5.357830   1.0    3.171851  7.989657e-02
# C(dx, Sum)               2.145492   1.0    1.270138  2.641548e-01
# Residual               103.040030  61.0         NaN           NaN

# %% [markdown]
# ## CD: correlations w/ coc use

# %%
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:          allo3d_volume   R-squared:                       0.056
# Model:                            OLS   Adj. R-squared:                 -0.037
# Method:                 Least Squares   F-statistic:                    0.6034
# Date:                Tue, 02 Aug 2022   Prob (F-statistic):              0.727
# Time:                        22:30:54   Log-Likelihood:                -359.86
# No. Observations:                  68   AIC:                             733.7
# Df Residuals:                      61   BIC:                             749.3
# Df Model:                           6
# Covariance Type:            nonrobust
# ==========================================================================================
#                              coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------
# Intercept                198.0485     82.884      2.389      0.020      32.312     363.785
# sex[T.male]                1.0841     15.083      0.072      0.943     -29.077      31.245
# cssa_5_coccravfreq_mri    -0.4941      3.357     -0.147      0.883      -7.208       6.219
# memory_mean              -34.0409     38.010     -0.896      0.374    -110.046      41.965
# wrat_standard_score       -0.0679      0.808     -0.084      0.933      -1.684       1.548
# age_years                  0.4773      0.719      0.664      0.509      -0.960       1.915
# race___white             -13.2056     13.766     -0.959      0.341     -40.732      14.321
# ==============================================================================
# Omnibus:                        0.584   Durbin-Watson:                   1.754
# Prob(Omnibus):                  0.747   Jarque-Bera (JB):                0.272
# Skew:                           0.148   Prob(JB):                        0.873
# Kurtosis:                       3.092   Cond. No.                     1.58e+03
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.58e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
demo_controls
# Out:
# ['sex', 'age_years', 'race___white']

# %%
task_preds_ = ['affil_tendency_mean', 'power_tendency_mean',
               'ego2d_angles_end_mean', 'ego_dists_end_mean',
               'allo_consistency_mean', 'allo2d_area', 'allo3d_volume']

cd = df[df['dx'] == 'CD']
coc_df = pd.DataFrame()
for coc in [c for c in df.columns if 'coc' in c]:
    try: 
        mask = cd[coc] > 0
        for pred in task_preds_:
            
#             r,p = scipy.stats.pearsonr(cd[coc][mask], cd[pred][mask])
            formula = pred + " ~  + " + coc + " + memory_mean + wrat_standard_score + ctq_total_score_2 + " + (' + ').join(demo_controls)
            model = ols(formula=formula, data=cd[mask])
            results = model.fit()
            ix = np.where(pd.DataFrame(results.pvalues).index == coc)[0][0]
            p = results.pvalues[ix]
            t = results.tvalues[ix]
            
            # shuld do ols...
            if p < 0.05: 
                coc_df.loc[len(coc_df), ['behav', 'coc', 'p', 't']] = [pred, coc, p, t]
#                 sns.regplot(x=coc, y=pred, data=df[mask], color=pal[1])
#                 plt.show()
    except:
        continue

# %%
[c for c in cd.columns if 'ctq' in c]
# Out:
# ['ctq_physical_abuse_score',
#  'ctq_emotional_abuse_score',
#  'ctq_sexual_abuse_score',
#  'ctq_emotional_neglect_score',
#  'ctq_physical_neglect_scale',
#  'ctq_minimization_score',
#  'ctq_total_score_2']

# %%
formula = "ego_dists_end_mean ~  + asi_coc_lifetime_years + memory_mean + wrat_standard_score + ctq_total_score_2 + " + (' + ').join(demo_controls)
model = ols(formula=formula, data=cd)
results = model.fit()
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:     ego_dists_end_mean   R-squared:                       0.469
# Model:                            OLS   Adj. R-squared:                  0.300
# Method:                 Least Squares   F-statistic:                     2.776
# Date:                Tue, 02 Aug 2022   Prob (F-statistic):             0.0314
# Time:                        22:41:33   Log-Likelihood:                -38.167
# No. Observations:                  30   AIC:                             92.33
# Df Residuals:                      22   BIC:                             103.5
# Df Model:                           7
# Covariance Type:            nonrobust
# ==========================================================================================
#                              coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------
# Intercept                 -0.7163      2.544     -0.282      0.781      -5.993       4.560
# sex[T.male]               -0.8808      0.567     -1.553      0.135      -2.057       0.296
# asi_coc_lifetime_years    -0.0841      0.024     -3.472      0.002      -0.134      -0.034
# memory_mean                0.7013      1.215      0.577      0.570      -1.819       3.221
# wrat_standard_score        0.0275      0.024      1.124      0.273      -0.023       0.078
# ctq_total_score_2          0.0030      0.010      0.293      0.772      -0.018       0.024
# age_years                  0.1296      0.033      3.871      0.001       0.060       0.199
# race___white              -0.2673      0.538     -0.497      0.624      -1.383       0.849
# ==============================================================================
# Omnibus:                        4.054   Durbin-Watson:                   2.225
# Prob(Omnibus):                  0.132   Jarque-Bera (JB):                2.272
# Skew:                           0.432   Prob(JB):                        0.321
# Kurtosis:                       1.965   Cond. No.                     1.77e+03
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.77e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
coc_df.sort_values(by='p')
# Out:
#                     behav                                         coc  \
# 8      ego_dists_end_mean                             coc_age_reg_use
# 4      ego_dists_end_mean                             coc_age_1st_use
# 7     affil_tendency_mean                             coc_age_reg_use
# 14            allo2d_area                                 coc_inpt_tx
# 15    affil_tendency_mean                      asi_coc_lifetime_years
# 3     affil_tendency_mean                             coc_age_1st_use
# 16     ego_dists_end_mean                      asi_coc_lifetime_years
# 11    affil_tendency_mean                               coc_dur_years
# 19    affil_tendency_mean                      stcq_screen_resist_coc
# 12     ego_dists_end_mean                               coc_dur_years
# 5   allo_consistency_mean                             coc_age_1st_use
# 23    power_tendency_mean                     stcq_mri_cocuse_perfect
# 20     ego_dists_end_mean                      stcq_screen_resist_coc
# 21    power_tendency_mean                  stcq_screen_cocuse_perfect
# 13  allo_consistency_mean                                 coc_inpt_tx
# 18            allo2d_area                          cssa_5_coccravfreq
# 6             allo2d_area                             coc_age_1st_use
# 17            allo2d_area                              cssa_4_coccrav
# 0           allo3d_volume  mentalizing_initial_screening_used_cocaine
# 2           allo3d_volume  mentalizing_initial_screening_cocaine_quit
# 10            allo2d_area                             coc_age_reg_use
# 9   allo_consistency_mean                             coc_age_reg_use
# 24  ego2d_angles_end_mean                     stcq_mri_cocuse_perfect
# 1   ego2d_angles_end_mean  mentalizing_initial_screening_cocaine_quit
# 22  ego2d_angles_end_mean                  stcq_screen_cocuse_perfect
#
#            p          t
# 8   0.000108   4.704546
# 4   0.000190   4.472252
# 7   0.000430  -4.139078
# 14  0.000485 -45.378331
# 15  0.001564   3.607292
# 3   0.001830  -3.541992
# 16  0.001868  -3.533399
# 11  0.002891   3.350808
# 19  0.003104  -3.565489
# 12  0.003619  -3.256207
# 5   0.005434   3.083197
# 23  0.016674   3.533697
# 20  0.018794   2.656374
# 21  0.019205   3.026650
# 13  0.020221  -6.925173
# 18  0.020992   2.559582
# 6   0.021371   2.477938
# 17  0.027562   2.424123
# 0   0.028209   2.349105
# 2   0.029661   2.373699
# 10  0.034671   2.251543
# 9   0.039233   2.192247
# 24  0.045093  -2.656124
# 1   0.046018   2.152470
# 22  0.046278  -2.417265

# %% [markdown]
# # Dots

# %%
nrows = 3 * len(np.unique(df['dx']))
fig, axs = plt.subplots(nrows, 5, figsize=(20, 3.75*nrows))
fig.subplots_adjust(top=0.95)
fig.text(0.5, 0.04, 'Affiliation', ha='center', fontsize=20)
fig.text(-0.01, 0.5, 'Power', va='center', rotation='vertical', fontsize=20)

dots_binedges = np.array([0,200,400,600,800,1000])
rank_binedges = np.array([0,1,2,3,4,5])
task_binedges = np.array([-1,-.6,-.2,.2,.6,1]) 

character_roles_ = character_roles # + ['mean']
# character_colors_ = character_colors # + ['grey']

for g, group in enumerate(np.unique(df['dx'])):
    print(group)
    df_ = df[df['dx'] == group]
    
    for c, char in enumerate(character_roles_):

        axs[0+(3*g),c].set_title(character_roles_[c].capitalize(), fontsize=20)

        # behav place
        task_affil = df_['affil_tendency_' + char]
        task_power = df_['power_tendency_' + char]
        axs[0+(3*g),c].hist2d(task_affil, task_power, bins=[task_binedges, task_binedges]) # color=character_colors_[c])
        axs[0+(3*g),c].set_ylabel('Behavioral coordinates', fontsize=20)
        axs[0+(3*g),c].axis([-1, 1, -1, 1])

        # dots place 
        dots_power = df_['dots_power_' + char] 
        dots_affil = df_['dots_affil_' + char]
        axs[1+(3*g),c].hist2d(dots_affil, dots_power, bins=[task_binedges, task_binedges]) #color=character_colors_[c])
        axs[1+(3*g),c].set_ylabel('Dots coordinates', fontsize=20)
        axs[1+(3*g),c].axis([-1, 1, -1, 1])

        # behav - dots
        H1, _, _ = np.histogram2d(task_affil, task_power, bins=[task_binedges,task_binedges])
        H2, _, _ = np.histogram2d(dots_affil, dots_power, bins=[task_binedges,task_binedges])
        H12 = H1.T - H2.T
        axs[2+(3*g),c].imshow(H12, interpolation=None, origin='lower',
                        extent=[task_binedges[0], task_binedges[-1], task_binedges[0], task_binedges[-1]], cmap='RdBu')
        axs[2+(3*g),c].set_ylabel('Difference', fontsize=20)

        if c > 0: [axs[r,c].axes.get_yaxis().set_visible(False) for r in np.arange(0,nrows)]
# Out:
# CD
# HC

# %% [markdown]
# ### Dots relationships

# %%
dots_cols = []
beh_cols  = []
for char in character_roles:
    dots_cols.append('dots_affil_' + char)
    dots_cols.append('dots_power_' + char)
    beh_cols.append('affil_tendency_' + char)
    beh_cols.append('power_tendency_' + char)

# add egocentric distance
for char in character_roles:
    
    char_mask = np.sum(np.isfinite(df[[c for c in dots_cols if char in c]]), 1) == 2
    xy = df[[c for c in dots_cols if char in c]][char_mask].values
    
    # from the theoretical pov
    xy_ego = xy - np.array([1, 0])
    df['dots_ego_dists_' + char] = np.nan
    df['dots_ego_dists_' + char][char_mask] = [l2_norm(v) for v in xy_ego]

    # from the empirical avoidance pov
    best_ref = np.array((6, -4)) / 6
    xy_best = xy - best_ref
    df['dots_best_dists_' + char] = np.nan
    df['dots_best_dists_' + char][char_mask] = [l2_norm(v) for v in xy_best]
    
for char in character_roles:
    dots_cols.append('dots_ego_dists_' + char)
    dots_cols.append('dots_best_dists_' + char)

df['dots_ego_dists_mean'] = np.mean(df[[c for c in dots_cols if 'ego_dists' in c]], 1)
df['dots_best_dists_mean'] = np.mean(df[[c for c in dots_cols if 'best_dists' in c]], 1)


pov_loc = np.array([1, 0])

# mask = (np.isfinite(df['dots_affil_first'])) & (np.isfinite(df['power_tendency_first']))
for s, sub in df.iterrows():
    sub_dists = []
    for c, char in enumerate(character_roles):
        
        task_loc = [sub['affil_tendency_' + char], sub['power_tendency_' + char]]
        dots_loc = [sub['dots_affil_' + char], sub['dots_power_' + char]] # dbl check that this is computed correctly...
        
        df.loc[s, 'distance_dots_' + char] = distance.euclidean(dots_loc, pov_loc)
        df.loc[s, 'distance_task_' + char] = distance.euclidean(task_loc, pov_loc) 
        df.loc[s, 'distance_diff_' + char] = distance.euclidean(dots_loc, task_loc)

df['distance_dots_mean'] = np.mean(df[['distance_dots_' + char for char in character_roles]], axis=1)
df['distance_task_mean'] = np.mean(df[['distance_task_' + char for char in character_roles]], axis=1)
df['distance_diff_mean'] = np.mean(df[['distance_diff_' + char for char in character_roles]], axis=1)
df.head(3)
# Out:
# //anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# //anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
X = sm.add_constant(df[['ego_dists_end_mean', 'dx'] + demo_controls])
X['sex'] = (X['sex']=='female') * 1
X['dx'] = (X['dx']=='HC') * 1
y = df['dots_ego_dists_mean']
model = sm.OLS(y, X, missing='drop')
results = model.fit()
display(results.summary())
# results.pvalues

# fig, ax = plt.subplots(figsize=(5,5))
# sns.regplot(x='iq_score', y='dots_best_dists_mean', data=df, color='purple')
# plt.show()
# Out:
# //anaconda3/lib/python3.7/site-packages/statsmodels/tsa/tsatools.py:117: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only
#   x = pd.concat(x[::order], 1)
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                              OLS Regression Results
# ===============================================================================
# Dep. Variable:     dots_ego_dists_mean   R-squared:                       0.095
# Model:                             OLS   Adj. R-squared:                  0.019
# Method:                  Least Squares   F-statistic:                     1.244
# Date:                 Fri, 29 Jul 2022   Prob (F-statistic):              0.300
# Time:                         12:16:36   Log-Likelihood:                -14.754
# No. Observations:                   65   AIC:                             41.51
# Df Residuals:                       59   BIC:                             54.55
# Df Model:                            5
# Covariance Type:             nonrobust
# ======================================================================================
#                          coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# const                  0.3231      0.290      1.113      0.270      -0.258       0.904
# ego_dists_end_mean     0.0309      0.034      0.900      0.372      -0.038       0.100
# dx                     0.0749      0.083      0.899      0.372      -0.092       0.242
# sex                   -0.0213      0.095     -0.223      0.824      -0.212       0.170
# age_years              0.0065      0.005      1.301      0.198      -0.003       0.016
# race___white          -0.0618      0.087     -0.707      0.482      -0.237       0.113
# ==============================================================================
# Omnibus:                        1.299   Durbin-Watson:                   1.954
# Prob(Omnibus):                  0.522   Jarque-Bera (JB):                1.324
# Skew:                           0.264   Prob(JB):                        0.516
# Kurtosis:                       2.541   Cond. No.                         359.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# ### Maybe a group diff in the correlation between "traveled" and perceived distance?

# %%
sns.regplot(x='dots_ego_dists_mean', y='ego_dists_mean_mean', data=hc, color=pal[0])
sns.regplot(x='dots_ego_dists_mean', y='ego_dists_mean_mean', data=cd, color=pal[1])
plt.show()

formula = "dots_ego_dists_mean ~ ego_dists_mean_mean * dx + memory_mean" # + (' + ').join(demo_controls)
model = ols(formula=formula, data=df)
results = model.fit()
display(results.summary())
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# //anaconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# //anaconda3/lib/python3.7/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# //anaconda3/lib/python3.7/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'dots_ego_dists_mean'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-24-72dabbcc7fb7> in <module>
# ----> 1 sns.regplot(x='dots_ego_dists_mean', y='ego_dists_mean_mean', data=hc, color=pal[0])
#       2 sns.regplot(x='dots_ego_dists_mean', y='ego_dists_mean_mean', data=cd, color=pal[1])
#       3 plt.show()
#       4
#       5 formula = "dots_ego_dists_mean ~ ego_dists_mean_mean * dx + memory_mean" # + (' + ').join(demo_controls)
#
# //anaconda3/lib/python3.7/site-packages/seaborn/_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# //anaconda3/lib/python3.7/site-packages/seaborn/regression.py in regplot(x, y, data, x_estimator, x_bins, x_ci, scatter, fit_reg, ci, n_boot, units, seed, order, logistic, lowess, robust, logx, x_partial, y_partial, truncate, dropna, x_jitter, y_jitter, label, color, marker, scatter_kws, line_kws, ax)
#     853                                  order, logistic, lowess, robust, logx,
#     854                                  x_partial, y_partial, truncate, dropna,
# --> 855                                  x_jitter, y_jitter, color, label)
#     856
#     857     if ax is None:
#
# //anaconda3/lib/python3.7/site-packages/seaborn/regression.py in __init__(self, x, y, data, x_estimator, x_bins, x_ci, scatter, fit_reg, ci, n_boot, units, seed, order, logistic, lowess, robust, logx, x_partial, y_partial, truncate, dropna, x_jitter, y_jitter, color, label)
#     108         # Extract the data vals from the arguments or passed dataframe
#     109         self.establish_variables(data, x=x, y=y, units=units,
# --> 110                                  x_partial=x_partial, y_partial=y_partial)
#     111
#     112         # Drop null observations
#
# //anaconda3/lib/python3.7/site-packages/seaborn/regression.py in establish_variables(self, data, **kws)
#      44         for var, val in kws.items():
#      45             if isinstance(val, str):
# ---> 46                 vector = data[val]
#      47             elif isinstance(val, list):
#      48                 vector = np.asarray(val)
#
# //anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    3456             if self.columns.nlevels > 1:
#    3457                 return self._getitem_multilevel(key)
# -> 3458             indexer = self.columns.get_loc(key)
#    3459             if is_integer(indexer):
#    3460                 indexer = [indexer]
#
# //anaconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
# -> 3363                 raise KeyError(key) from err
#    3364
#    3365         if is_scalar(key) and isna(key) and not self.hasnans:
#
# KeyError: 'dots_ego_dists_mean'

# %%
fig, axs = plt.subplots(1, 3, figsize=(17,5))
for d, dist in enumerate(['distance_task','distance_dots','distance_diff']):

    melted = pd.melt(df, id_vars=['sub_id', 'dx'], value_vars=[dist + '_' + char for char in character_roles + ['mean']])
    sns.barplot(x='dx', y='value', hue='variable', data=melted, edgecolor='.2', ax=axs[d])
    sns.stripplot(x='dx', y='value', hue='variable', data=melted, 
                 dodge=True, edgecolor=".2", alpha=.6, linewidth=1, ax=axs[d])
    axs[d].set_title(dist)
    handles,labels = plt.gca().get_legend_handles_labels()
    if d == 2:
        axs[d].legend(title='', loc='upper right', handles=handles[6:],
                   frameon=False, bbox_to_anchor=(1.6, 1), borderaxespad=0)
    else:
        axs[d].get_legend().remove()
plt.show()

# %% [markdown]
# ### ANOVAs & T-tests

# %%
long = pd.melt(dist_df, id_vars=['sub_id', 'dx', 'sex', 'race___white', 'ctq_total_score_2'], 
               value_vars=['distance_task.' + char for char in character_roles])
model = ols("value ~ C(sex, Sum) + C(race___white, Sum) + C(dx, Sum) + ctq_total_score_2", data=long).fit()
aov_table = sm.stats.anova_lm(model, typ=3)
display(aov_table)
# Out:
#                          sum_sq     df           F        PR(>F)
# Intercept             47.794178    1.0  290.963140  2.123564e-47
# C(sex, Sum)            0.102095    1.0    0.621535  4.310351e-01
# C(race___white, Sum)   0.318319    1.0    1.937872  1.648233e-01
# C(dx, Sum)             0.034970    1.0    0.212894  6.448078e-01
# ctq_total_score_2      0.355263    1.0    2.162782  1.423272e-01
# Residual              55.027760  335.0         NaN           NaN

# %% [markdown]
# ### Correlations w/ drug use

# %%
task_preds_ = ['affil_tendency_mean', 'power_tendency_mean',
               'ego2d_angles_end_mean','ego_dists_end_mean',
               'allo_consistency_mean','allo2d_area','allo3d_volume',
               'rt_affil_mean','rt_power_mean']
for coc in ['coc_dur_years', 'coc_age_reg_use', 'coc_age_1st_use']:
    mask = df[coc] > 0
    for d, dist in enumerate(['distance_dots_mean', 'distance_diff_mean']):
        r,p = scipy.stats.pearsonr(df[coc][mask], df[dist][mask])
        if p < 0.05: 
            sns.regplot(x=coc, y=dist, data=df[mask])
            plt.show()

# %% [markdown]
# ### Self-rank

# %%
# from scipy.stats import rankdata
# def rankdata_rev(array, method='average'):
#     return array.shape[1] - rankdata(array, method=method, axis=1) + 1
# df['self_power'] = 0
# ranked_power = rankdata_rev(df[['dots_power.norm.' + char for char in character_roles] + ['self_power']])
# df['self_power.rank'] = ranked_power[:,5]

# %%
# long = pd.melt(df, id_vars=['sub_id', 'dx', 'sex', 'race___white', 'ctq_total_score_2'], 
#                value_vars=['self_power.rank'])
# model = ols("value ~ C(sex, Sum) + C(race___white, Sum) + C(ctq_total_score_2, Sum) + C(dx, Sum)", data=long).fit()
# aov_table = sm.stats.anova_lm(model, typ=3)
# display(aov_table)

# %% [markdown]
# # Correlations w/ HPC betas: nada

# %%
[c for c in df.columns if 'HPC' in c]
# Out:
# ['ant_L_HPC', 'mid_L_HPC', 'post_L_HPC']

# %% [markdown]
# # Correlations w/ functioning

# %%
task_preds_ = ['affil_tendency_mean', 'power_tendency_mean',
               'ego_dists_end_mean','allo_consistency_mean']
#                'ant_L_HPC', 'post_L_HPC', 'mid_L_HPC', 'rt_affil_mean', 'rt_power_mean']
lsas = ['lsas_social_interaction_fear_subscale', 'lsas_performance_fear_subscale',
        'lsas_social_interaction_avoidance_subscale', 'lsas_performance_avoidance_subscale',
        'lsas_total_score']
sni = ['sni_num_ppl', 'sni_network_div']
isel = ['isel_scr_appraisal_subscale', 'isel_scr_tangible_subscale', 'isel_scr_selfesteem_subscale']
ctq = ['ctq_physical_abuse_score','ctq_emotional_abuse_score',
       'ctq_sexual_abuse_score', 'ctq_emotional_neglect_score','ctq_physical_neglect_scale',
       'ctq_minimization_score', 'ctq_total_score_2']

questionnaires = ['ctq_total_score_2', 'coc_age_1st_use', 'alc_age_1st_use']
for var in task_preds_:
    if 'angles' not in var:
        hc = df[df['dx'] == 'HC']
        cd = df[df['dx'] == 'CD'] 
        fig, axs = plt.subplots(1, len(questionnaires), figsize=(len(questionnaires)*4.5, 4), sharey=True)
        for q, ques in enumerate(questionnaires):
            sns.regplot(x=ques, y=var, data=hc, color=pal[0], ax=axs[q])
            sns.regplot(x=ques, y=var, data=cd, color=pal[1], ax=axs[q])
            axs[q].set_xlabel(ques, fontsize=15)
            axs[q].set_ylabel(var, fontsize=15)
        plt.tight_layout()

# %%
# questionnaires = lsas
# for var in task_preds:
#     if 'angles' not in var:
#         hc = df[df['dx'] == 'HC']
#         cd = df[df['dx'] == 'CD'] 
#         for q, ques in enumerate(questionnaires):
#             X = sm.add_constant(df[[var, 'dx'] + demo_controls])
#             X['sex'] = (X['sex']=='female') * 1
#             X['dx'] = (X['dx']=='HC') * 1
#             y = df[ques]
#             model = sm.OLS(y, X, missing='drop')
#             results = model.fit()
#             if results.pvalues[1] < 0.05:
#                 display(results.summary())

# %% [markdown]
# ## Social anxiety

# %%
lsas = 'lsas_total_score'
sns.histplot(hc[lsas], color=pal[0], bins=10)
sns.histplot(cd[lsas], color=pal[1], bins=10)

hc_ = hc[lsas]
cd_ = cd[lsas]
scipy.stats.mannwhitneyu(hc_, cd_, alternative='greater', 
                         use_continuity=False, axis=0, method='auto')
# Out:
# MannwhitneyuResult(statistic=541.0, pvalue=0.6399820824574732)

# %% [markdown]
# ## Addiction severity

# %% [markdown]
# ## Age of first coc use

# %%
task_preds_ = ['affil_tendency_mean', 'power_tendency_mean',
               'ego2d_angles_end_mean','ego_dists_end_mean',
               'allo_consistency_mean','allo2d_area','allo3d_volume',
               'rt_affil_mean','rt_power_mean']
dists = ['distance_dots_mean', 'distance_diff_mean']
cocs = ['coc_dur_years', 'coc_age_reg_use', 'coc_age_1st_use']
# mask = df[coc] > 0
# 'lsas_total_score', 'sni_num_ppl'

# %%
preds_ = ['mid_L_HPC', 'allo_consistency_mean', 'affil_tendency_mean', 'ego_dists_end_mean', 'distance_diff_mean']
for pred in preds_:
    
    #     y = cd[pred]
    #     X = sm.add_constant(cd[['coc_age_1st_use', 'ctq_total_score_2'] + demo_controls])
    #     X['sex'] = (X['sex']=='female') * 1 # dummy-coded 
    #     model = sm.OLS(y, X, missing='drop')
    
    formula = pred + " ~ coc_age_reg_use + ctq_total_score_2 + memory_mean + wrat_standard_score + " + (' + ').join(demo_controls)
    model = ols(formula=formula, data=cd)
    results = model.fit()
    display(results.summary())
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              mid_L_HPC   R-squared:                       0.238
# Model:                            OLS   Adj. R-squared:                 -0.016
# Method:                 Least Squares   F-statistic:                    0.9376
# Date:                Wed, 27 Jul 2022   Prob (F-statistic):              0.499
# Time:                        10:59:38   Log-Likelihood:                -5.8365
# No. Observations:                  29   AIC:                             27.67
# Df Residuals:                      21   BIC:                             38.61
# Df Model:                           7
# Covariance Type:            nonrobust
# =======================================================================================
#                           coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# Intercept               0.8459      0.860      0.983      0.337      -0.943       2.635
# sex[T.male]             0.0964      0.194      0.498      0.624      -0.307       0.499
# coc_age_reg_use        -0.0083      0.009     -0.911      0.372      -0.027       0.011
# ctq_total_score_2      -0.0063      0.004     -1.782      0.089      -0.014       0.001
# memory_mean            -0.0201      0.419     -0.048      0.962      -0.890       0.850
# wrat_standard_score    -0.0076      0.008     -0.908      0.374      -0.025       0.010
# age_years               0.0068      0.008      0.803      0.431      -0.011       0.024
# race___white            0.0761      0.203      0.374      0.712      -0.347       0.499
# ==============================================================================
# Omnibus:                        0.948   Durbin-Watson:                   2.749
# Prob(Omnibus):                  0.623   Jarque-Bera (JB):                0.637
# Skew:                           0.358   Prob(JB):                        0.727
# Kurtosis:                       2.876   Cond. No.                     1.71e+03
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.71e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                               OLS Regression Results
# =================================================================================
# Dep. Variable:     allo_consistency_mean   R-squared:                       0.431
# Model:                               OLS   Adj. R-squared:                  0.241
# Method:                    Least Squares   F-statistic:                     2.270
# Date:                   Wed, 27 Jul 2022   Prob (F-statistic):             0.0690
# Time:                           10:59:38   Log-Likelihood:                 36.042
# No. Observations:                     29   AIC:                            -56.08
# Df Residuals:                         21   BIC:                            -45.15
# Df Model:                              7
# Covariance Type:               nonrobust
# =======================================================================================
#                           coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# Intercept               0.0227      0.203      0.112      0.912      -0.399       0.445
# sex[T.male]             0.0096      0.046      0.210      0.836      -0.085       0.105
# coc_age_reg_use         0.0051      0.002      2.357      0.028       0.001       0.010
# ctq_total_score_2       0.0009      0.001      1.130      0.271      -0.001       0.003
# memory_mean             0.0536      0.099      0.543      0.593      -0.152       0.259
# wrat_standard_score     0.0007      0.002      0.355      0.726      -0.003       0.005
# age_years               0.0024      0.002      1.208      0.241      -0.002       0.007
# race___white           -0.0416      0.048     -0.866      0.396      -0.141       0.058
# ==============================================================================
# Omnibus:                        0.123   Durbin-Watson:                   1.450
# Prob(Omnibus):                  0.941   Jarque-Bera (JB):                0.217
# Skew:                          -0.135   Prob(JB):                        0.897
# Kurtosis:                       2.674   Cond. No.                     1.71e+03
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.71e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                              OLS Regression Results
# ===============================================================================
# Dep. Variable:     affil_tendency_mean   R-squared:                       0.554
# Model:                             OLS   Adj. R-squared:                  0.405
# Method:                  Least Squares   F-statistic:                     3.721
# Date:                 Wed, 27 Jul 2022   Prob (F-statistic):            0.00898
# Time:                         10:59:38   Log-Likelihood:                 16.581
# No. Observations:                   29   AIC:                            -17.16
# Df Residuals:                       21   BIC:                            -6.223
# Df Model:                            7
# Covariance Type:             nonrobust
# =======================================================================================
#                           coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# Intercept               1.1221      0.397      2.825      0.010       0.296       1.948
# sex[T.male]             0.1024      0.089      1.145      0.265      -0.084       0.288
# coc_age_reg_use        -0.0184      0.004     -4.367      0.000      -0.027      -0.010
# ctq_total_score_2      -0.0022      0.002     -1.326      0.199      -0.006       0.001
# memory_mean            -0.1156      0.193     -0.598      0.556      -0.517       0.286
# wrat_standard_score     0.0008      0.004      0.207      0.838      -0.007       0.009
# age_years              -0.0123      0.004     -3.145      0.005      -0.020      -0.004
# race___white           -0.1346      0.094     -1.434      0.166      -0.330       0.061
# ==============================================================================
# Omnibus:                        0.630   Durbin-Watson:                   2.173
# Prob(Omnibus):                  0.730   Jarque-Bera (JB):                0.719
# Skew:                          -0.224   Prob(JB):                        0.698
# Kurtosis:                       2.372   Cond. No.                     1.71e+03
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.71e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:     ego_dists_end_mean   R-squared:                       0.614
# Model:                            OLS   Adj. R-squared:                  0.486
# Method:                 Least Squares   F-statistic:                     4.778
# Date:                Wed, 27 Jul 2022   Prob (F-statistic):            0.00242
# Time:                        10:59:38   Log-Likelihood:                -32.751
# No. Observations:                  29   AIC:                             81.50
# Df Residuals:                      21   BIC:                             92.44
# Df Model:                           7
# Covariance Type:            nonrobust
# =======================================================================================
#                           coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# Intercept              -0.5476      2.176     -0.252      0.804      -5.074       3.978
# sex[T.male]            -0.6757      0.490     -1.378      0.183      -1.695       0.344
# coc_age_reg_use         0.1121      0.023      4.859      0.000       0.064       0.160
# ctq_total_score_2       0.0102      0.009      1.143      0.266      -0.008       0.029
# memory_mean             0.7416      1.059      0.701      0.491      -1.460       2.943
# wrat_standard_score     0.0028      0.021      0.132      0.896      -0.041       0.047
# age_years               0.0748      0.021      3.498      0.002       0.030       0.119
# race___white            0.5451      0.514      1.059      0.301      -0.525       1.615
# ==============================================================================
# Omnibus:                        0.466   Durbin-Watson:                   2.146
# Prob(Omnibus):                  0.792   Jarque-Bera (JB):                0.599
# Skew:                          -0.166   Prob(JB):                        0.741
# Kurtosis:                       2.379   Cond. No.                     1.71e+03
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.71e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:     distance_diff_mean   R-squared:                       0.515
# Model:                            OLS   Adj. R-squared:                  0.353
# Method:                 Least Squares   F-statistic:                     3.180
# Date:                Wed, 27 Jul 2022   Prob (F-statistic):             0.0186
# Time:                        10:59:38   Log-Likelihood:                 7.9287
# No. Observations:                  29   AIC:                            0.1426
# Df Residuals:                      21   BIC:                             11.08
# Df Model:                           7
# Covariance Type:            nonrobust
# =======================================================================================
#                           coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# Intercept               0.1862      0.535      0.348      0.731      -0.927       1.299
# sex[T.male]            -0.3149      0.121     -2.613      0.016      -0.566      -0.064
# coc_age_reg_use         0.0187      0.006      3.288      0.004       0.007       0.030
# ctq_total_score_2       0.0009      0.002      0.397      0.695      -0.004       0.005
# memory_mean             0.3505      0.260      1.346      0.193      -0.191       0.892
# wrat_standard_score    -0.0018      0.005     -0.350      0.730      -0.013       0.009
# age_years               0.0100      0.005      1.893      0.072      -0.001       0.021
# race___white           -0.1948      0.127     -1.540      0.139      -0.458       0.068
# ==============================================================================
# Omnibus:                        2.975   Durbin-Watson:                   2.001
# Prob(Omnibus):                  0.226   Jarque-Bera (JB):                2.061
# Skew:                           0.651   Prob(JB):                        0.357
# Kurtosis:                       3.091   Cond. No.                     1.71e+03
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.71e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %% [markdown]
# ### Age of first alc use - way to combine both samples...

# %%
# Age of alc first use as proxy for HCs
# hc = df[df['dx'] == 'HC']
formula = "ego_dists_end_mean ~ alc_age_1st_use + ctq_total_score_2 + memory_mean + wrat_standard_score + dx + " + (' + ').join(demo_controls)
model = ols(formula=formula, data=df)
results = model.fit()
display(results.summary())
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:     ego_dists_end_mean   R-squared:                       0.250
# Model:                            OLS   Adj. R-squared:                  0.132
# Method:                 Least Squares   F-statistic:                     2.123
# Date:                Wed, 27 Jul 2022   Prob (F-statistic):             0.0503
# Time:                        11:00:57   Log-Likelihood:                -87.418
# No. Observations:                  60   AIC:                             192.8
# Df Residuals:                      51   BIC:                             211.7
# Df Model:                           8
# Covariance Type:            nonrobust
# =======================================================================================
#                           coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# Intercept               2.4331      2.152      1.131      0.263      -1.887       6.753
# dx[T.HC]                0.0901      0.315      0.286      0.776      -0.542       0.722
# sex[T.male]            -0.1853      0.388     -0.478      0.635      -0.964       0.593
# alc_age_1st_use         0.0409      0.030      1.350      0.183      -0.020       0.102
# ctq_total_score_2       0.0032      0.008      0.401      0.690      -0.013       0.019
# memory_mean             1.4345      0.892      1.608      0.114      -0.356       3.225
# wrat_standard_score    -0.0004      0.020     -0.021      0.983      -0.040       0.039
# age_years               0.0588      0.017      3.362      0.001       0.024       0.094
# race___white           -0.2723      0.340     -0.801      0.427      -0.954       0.410
# ==============================================================================
# Omnibus:                        3.771   Durbin-Watson:                   2.142
# Prob(Omnibus):                  0.152   Jarque-Bera (JB):                2.250
# Skew:                           0.246   Prob(JB):                        0.325
# Kurtosis:                       2.188   Cond. No.                     1.87e+03
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.87e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %% [markdown]
# ## Childhood trauma (CTQ)

# %%
sns.regplot(y='ctq_total_score_2', x='allo_consistency_mean', data=hc, color=pal[0])
sns.regplot(y='ctq_total_score_2', x='allo_consistency_mean', data=cd, color=pal[1])
plt.show()

sns.regplot(y='sni_network_div', x='allo_consistency_mean', data=hc, color=pal[0])
sns.regplot(y='sni_network_div', x='allo_consistency_mean', data=cd, color=pal[1])
plt.show()

sns.regplot(y='sni_network_div', x='ctq_total_score_2', data=hc, color=pal[0])
sns.regplot(y='sni_network_div', x='ctq_total_score_2', data=cd, color=pal[1])
plt.show()

# %%
cd = df[df['dx'] == 'CD']
hc = df[df['dx'] == 'HC']
x = 'ctq_total_score_2'
y = 'allo_consistency_mean'
sns.regplot(y=y, x=x, data=cd, color=pal[1])
sns.regplot(y=y, x=x, data=hc, color=pal[0])
plt.show()
formula = "ctq_total_score_2 ~ allo_consistency_mean + power_consistency_mean + affil_consistency_mean + memory_mean + wrat_standard_score + dx + " + (' + ').join(demo_controls)
model = ols(formula=formula, data=df)
results = model.fit()
display(results.summary())
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:      ctq_total_score_2   R-squared:                       0.219
# Model:                            OLS   Adj. R-squared:                  0.091
# Method:                 Least Squares   F-statistic:                     1.716
# Date:                Thu, 28 Jul 2022   Prob (F-statistic):              0.107
# Time:                        16:52:14   Log-Likelihood:                -277.51
# No. Observations:                  65   AIC:                             575.0
# Df Residuals:                      55   BIC:                             596.8
# Df Model:                           9
# Covariance Type:            nonrobust
# ==========================================================================================
#                              coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------
# Intercept                 19.9060     33.116      0.601      0.550     -46.460      86.272
# dx[T.HC]                  -6.8001      5.148     -1.321      0.192     -17.118       3.517
# sex[T.male]               -8.6904      6.630     -1.311      0.195     -21.977       4.596
# allo_consistency_mean    218.9787     61.446      3.564      0.001      95.837     342.120
# power_consistency_mean   -71.6749     31.493     -2.276      0.027    -134.788      -8.561
# affil_consistency_mean   -68.1498     29.339     -2.323      0.024    -126.947      -9.353
# memory_mean              -10.9598     15.668     -0.699      0.487     -42.360      20.440
# wrat_standard_score       -0.0499      0.313     -0.159      0.874      -0.677       0.577
# age_years                 -0.0112      0.285     -0.039      0.969      -0.582       0.559
# race___white               6.6091      5.539      1.193      0.238      -4.491      17.709
# ==============================================================================
# Omnibus:                        4.953   Durbin-Watson:                   2.088
# Prob(Omnibus):                  0.084   Jarque-Bera (JB):                4.647
# Skew:                           0.655   Prob(JB):                       0.0979
# Kurtosis:                       2.971   Cond. No.                     3.54e+03
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 3.54e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %% [markdown]
# ### Diff subscores

# %%
preds_ = ['allo_consistency_mean']  # 'post_L_HPC', 'sni_num_ppl'
for pred in preds_:
    
    for ctq in [c for c in df.columns if 'ctq' in c]:
    
    #     y = df[pred]
    #     X = sm.add_constant(df[['ctq_total_score_2', 'memory_mean', 'dx'] + demo_controls])
    #     X['sex'] = (X['sex']=='female') * 1
    #     X['dx'] = (X['dx']=='CD') * 1
    #     model = sm.OLS(y, X, missing='drop')

        formula = pred + " ~ " + ctq + " + memory_mean + wrat_standard_score + dx + " + (' + ').join(demo_controls)
        model = ols(formula=formula, data=df)
        results = model.fit()
        display(results.summary())
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                               OLS Regression Results
# =================================================================================
# Dep. Variable:     allo_consistency_mean   R-squared:                       0.212
# Model:                               OLS   Adj. R-squared:                  0.115
# Method:                    Least Squares   F-statistic:                     2.184
# Date:                   Wed, 27 Jul 2022   Prob (F-statistic):             0.0491
# Time:                           10:58:28   Log-Likelihood:                 70.839
# No. Observations:                     65   AIC:                            -125.7
# Df Residuals:                         57   BIC:                            -108.3
# Df Model:                              7
# Covariance Type:               nonrobust
# ============================================================================================
#                                coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------
# Intercept                    0.2063      0.152      1.354      0.181      -0.099       0.511
# dx[T.HC]                     0.0240      0.023      1.047      0.300      -0.022       0.070
# sex[T.male]                  0.0095      0.029      0.325      0.746      -0.049       0.068
# ctq_physical_abuse_score     0.0042      0.002      2.044      0.046    8.47e-05       0.008
# memory_mean                  0.0996      0.066      1.506      0.138      -0.033       0.232
# wrat_standard_score          0.0005      0.001      0.362      0.718      -0.002       0.003
# age_years                    0.0011      0.001      0.864      0.391      -0.001       0.004
# race___white                -0.0539      0.024     -2.201      0.032      -0.103      -0.005
# ==============================================================================
# Omnibus:                        2.896   Durbin-Watson:                   1.381
# Prob(Omnibus):                  0.235   Jarque-Bera (JB):                2.088
# Skew:                           0.399   Prob(JB):                        0.352
# Kurtosis:                       3.367   Cond. No.                     1.66e+03
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.66e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                               OLS Regression Results
# =================================================================================
# Dep. Variable:     allo_consistency_mean   R-squared:                       0.228
# Model:                               OLS   Adj. R-squared:                  0.133
# Method:                    Least Squares   F-statistic:                     2.404
# Date:                   Wed, 27 Jul 2022   Prob (F-statistic):             0.0315
# Time:                           10:58:28   Log-Likelihood:                 71.524
# No. Observations:                     65   AIC:                            -127.0
# Df Residuals:                         57   BIC:                            -109.7
# Df Model:                              7
# Covariance Type:               nonrobust
# =============================================================================================
#                                 coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------
# Intercept                     0.2176      0.149      1.463      0.149      -0.080       0.515
# dx[T.HC]                      0.0185      0.023      0.814      0.419      -0.027       0.064
# sex[T.male]                   0.0203      0.029      0.709      0.481      -0.037       0.078
# ctq_emotional_abuse_score     0.0043      0.002      2.341      0.023       0.001       0.008
# memory_mean                   0.0956      0.066      1.458      0.150      -0.036       0.227
# wrat_standard_score           0.0003      0.001      0.209      0.835      -0.003       0.003
# age_years                     0.0013      0.001      1.006      0.319      -0.001       0.004
# race___white                 -0.0620      0.024     -2.544      0.014      -0.111      -0.013
# ==============================================================================
# Omnibus:                        2.239   Durbin-Watson:                   1.333
# Prob(Omnibus):                  0.327   Jarque-Bera (JB):                1.728
# Skew:                           0.396   Prob(JB):                        0.422
# Kurtosis:                       3.102   Cond. No.                     1.64e+03
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.64e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                               OLS Regression Results
# =================================================================================
# Dep. Variable:     allo_consistency_mean   R-squared:                       0.184
# Model:                               OLS   Adj. R-squared:                  0.084
# Method:                    Least Squares   F-statistic:                     1.836
# Date:                   Wed, 27 Jul 2022   Prob (F-statistic):             0.0978
# Time:                           10:58:28   Log-Likelihood:                 69.726
# No. Observations:                     65   AIC:                            -123.5
# Df Residuals:                         57   BIC:                            -106.1
# Df Model:                              7
# Covariance Type:               nonrobust
# ==========================================================================================
#                              coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------
# Intercept                  0.2798      0.150      1.864      0.068      -0.021       0.581
# dx[T.HC]                   0.0284      0.024      1.201      0.235      -0.019       0.076
# sex[T.male]                0.0292      0.030      0.969      0.336      -0.031       0.090
# ctq_sexual_abuse_score     0.0030      0.002      1.454      0.151      -0.001       0.007
# memory_mean                0.1109      0.067      1.656      0.103      -0.023       0.245
# wrat_standard_score       -0.0002      0.001     -0.127      0.900      -0.003       0.003
# age_years                  0.0010      0.001      0.787      0.435      -0.002       0.004
# race___white              -0.0590      0.025     -2.358      0.022      -0.109      -0.009
# ==============================================================================
# Omnibus:                        0.280   Durbin-Watson:                   1.387
# Prob(Omnibus):                  0.869   Jarque-Bera (JB):                0.199
# Skew:                           0.131   Prob(JB):                        0.906
# Kurtosis:                       2.929   Cond. No.                     1.60e+03
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.6e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                               OLS Regression Results
# =================================================================================
# Dep. Variable:     allo_consistency_mean   R-squared:                       0.255
# Model:                               OLS   Adj. R-squared:                  0.163
# Method:                    Least Squares   F-statistic:                     2.783
# Date:                   Wed, 27 Jul 2022   Prob (F-statistic):             0.0146
# Time:                           10:58:28   Log-Likelihood:                 72.670
# No. Observations:                     65   AIC:                            -129.3
# Df Residuals:                         57   BIC:                            -111.9
# Df Model:                              7
# Covariance Type:               nonrobust
# ===============================================================================================
#                                   coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------
# Intercept                       0.2178      0.145      1.498      0.140      -0.073       0.509
# dx[T.HC]                        0.0270      0.022      1.208      0.232      -0.018       0.072
# sex[T.male]                     0.0224      0.028      0.795      0.430      -0.034       0.079
# ctq_emotional_neglect_score     0.0058      0.002      2.779      0.007       0.002       0.010
# memory_mean                     0.1230      0.064      1.918      0.060      -0.005       0.251
# wrat_standard_score         -1.452e-05      0.001     -0.010      0.992      -0.003       0.003
# age_years                       0.0011      0.001      0.853      0.397      -0.001       0.004
# race___white                   -0.0541      0.024     -2.276      0.027      -0.102      -0.007
# ==============================================================================
# Omnibus:                        2.532   Durbin-Watson:                   1.490
# Prob(Omnibus):                  0.282   Jarque-Bera (JB):                2.297
# Skew:                           0.367   Prob(JB):                        0.317
# Kurtosis:                       2.444   Cond. No.                     1.63e+03
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.63e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                               OLS Regression Results
# =================================================================================
# Dep. Variable:     allo_consistency_mean   R-squared:                       0.211
# Model:                               OLS   Adj. R-squared:                  0.114
# Method:                    Least Squares   F-statistic:                     2.172
# Date:                   Wed, 27 Jul 2022   Prob (F-statistic):             0.0503
# Time:                           10:58:28   Log-Likelihood:                 70.800
# No. Observations:                     65   AIC:                            -125.6
# Df Residuals:                         57   BIC:                            -108.2
# Df Model:                              7
# Covariance Type:               nonrobust
# ==============================================================================================
#                                  coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------
# Intercept                      0.2294      0.150      1.529      0.132      -0.071       0.530
# dx[T.HC]                       0.0320      0.023      1.366      0.177      -0.015       0.079
# sex[T.male]                    0.0328      0.030      1.106      0.273      -0.027       0.092
# ctq_physical_neglect_scale     0.0095      0.005      2.025      0.048       0.000       0.019
# memory_mean                    0.1082      0.066      1.641      0.106      -0.024       0.240
# wrat_standard_score           -0.0002      0.001     -0.158      0.875      -0.003       0.003
# age_years                      0.0012      0.001      0.911      0.366      -0.001       0.004
# race___white                  -0.0571      0.024     -2.332      0.023      -0.106      -0.008
# ==============================================================================
# Omnibus:                        3.033   Durbin-Watson:                   1.442
# Prob(Omnibus):                  0.219   Jarque-Bera (JB):                2.239
# Skew:                           0.423   Prob(JB):                        0.326
# Kurtosis:                       3.335   Cond. No.                     1.63e+03
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.63e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                               OLS Regression Results
# =================================================================================
# Dep. Variable:     allo_consistency_mean   R-squared:                       0.173
# Model:                               OLS   Adj. R-squared:                  0.072
# Method:                    Least Squares   F-statistic:                     1.708
# Date:                   Wed, 27 Jul 2022   Prob (F-statistic):              0.125
# Time:                           10:58:28   Log-Likelihood:                 69.305
# No. Observations:                     65   AIC:                            -122.6
# Df Residuals:                         57   BIC:                            -105.2
# Df Model:                              7
# Covariance Type:               nonrobust
# ==========================================================================================
#                              coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------
# Intercept                  0.3072      0.152      2.015      0.049       0.002       0.613
# dx[T.HC]                   0.0217      0.024      0.923      0.360      -0.025       0.069
# sex[T.male]                0.0219      0.030      0.737      0.464      -0.038       0.081
# ctq_minimization_score    -0.0128      0.011     -1.164      0.249      -0.035       0.009
# memory_mean                0.1132      0.067      1.679      0.099      -0.022       0.248
# wrat_standard_score        0.0001      0.001      0.084      0.933      -0.003       0.003
# age_years                  0.0010      0.001      0.752      0.455      -0.002       0.004
# race___white              -0.0596      0.025     -2.353      0.022      -0.110      -0.009
# ==============================================================================
# Omnibus:                        1.134   Durbin-Watson:                   1.510
# Prob(Omnibus):                  0.567   Jarque-Bera (JB):                0.782
# Skew:                           0.267   Prob(JB):                        0.676
# Kurtosis:                       3.057   Cond. No.                     1.62e+03
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.62e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                               OLS Regression Results
# =================================================================================
# Dep. Variable:     allo_consistency_mean   R-squared:                       0.246
# Model:                               OLS   Adj. R-squared:                  0.153
# Method:                    Least Squares   F-statistic:                     2.651
# Date:                   Wed, 27 Jul 2022   Prob (F-statistic):             0.0191
# Time:                           10:58:28   Log-Likelihood:                 72.276
# No. Observations:                     65   AIC:                            -128.6
# Df Residuals:                         57   BIC:                            -111.2
# Df Model:                              7
# Covariance Type:               nonrobust
# =======================================================================================
#                           coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# Intercept               0.2095      0.147      1.425      0.160      -0.085       0.504
# dx[T.HC]                0.0270      0.022      1.198      0.236      -0.018       0.072
# sex[T.male]             0.0234      0.028      0.827      0.412      -0.033       0.080
# ctq_total_score_2       0.0014      0.001      2.635      0.011       0.000       0.003
# memory_mean             0.1039      0.064      1.611      0.113      -0.025       0.233
# wrat_standard_score     0.0001      0.001      0.099      0.921      -0.003       0.003
# age_years               0.0011      0.001      0.880      0.382      -0.001       0.004
# race___white           -0.0588      0.024     -2.453      0.017      -0.107      -0.011
# ==============================================================================
# Omnibus:                        1.635   Durbin-Watson:                   1.343
# Prob(Omnibus):                  0.442   Jarque-Bera (JB):                1.319
# Skew:                           0.349   Prob(JB):                        0.517
# Kurtosis:                       2.985   Cond. No.                     1.75e+03
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.75e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %% [markdown]
# ### All subscores in same model

# %%
formula = "allo_consistency_mean ~ memory_mean + wrat_standard_score + dx + " + (' + ').join(demo_controls) + " + " + (' + ').join([c for c in df.columns if 'ctq' in c])
model = ols(formula=formula, data=df)
results = model.fit()
display(results.summary())
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                               OLS Regression Results
# =================================================================================
# Dep. Variable:     allo_consistency_mean   R-squared:                       0.267
# Model:                               OLS   Adj. R-squared:                  0.098
# Method:                    Least Squares   F-statistic:                     1.579
# Date:                   Wed, 27 Jul 2022   Prob (F-statistic):              0.127
# Time:                           01:46:45   Log-Likelihood:                 73.215
# No. Observations:                     65   AIC:                            -120.4
# Df Residuals:                         52   BIC:                            -92.16
# Df Model:                             12
# Covariance Type:               nonrobust
# ===============================================================================================
#                                   coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------
# Intercept                       0.1972      0.160      1.231      0.224      -0.124       0.519
# dx[T.HC]                        0.0227      0.025      0.900      0.372      -0.028       0.073
# sex[T.male]                     0.0225      0.033      0.689      0.494      -0.043       0.088
# memory_mean                     0.1120      0.068      1.649      0.105      -0.024       0.248
# wrat_standard_score          9.612e-05      0.002      0.063      0.950      -0.003       0.003
# age_years                       0.0012      0.001      0.918      0.363      -0.001       0.004
# race___white                   -0.0579      0.026     -2.262      0.028      -0.109      -0.007
# ctq_physical_abuse_score       -0.0018      0.004     -0.478      0.635      -0.009       0.006
# ctq_emotional_abuse_score       0.0018      0.004      0.438      0.663      -0.006       0.010
# ctq_sexual_abuse_score         -0.0014      0.003     -0.518      0.607      -0.007       0.004
# ctq_emotional_neglect_score     0.0036      0.003      1.073      0.288      -0.003       0.010
# ctq_physical_neglect_scale     -0.0011      0.006     -0.173      0.863      -0.014       0.011
# ctq_minimization_score          0.0021      0.013      0.160      0.873      -0.024       0.028
# ctq_total_score_2               0.0011      0.001      1.231      0.224      -0.001       0.003
# ==============================================================================
# Omnibus:                        2.456   Durbin-Watson:                   1.417
# Prob(Omnibus):                  0.293   Jarque-Bera (JB):                2.392
# Skew:                           0.416   Prob(JB):                        0.302
# Kurtosis:                       2.565   Cond. No.                     3.67e+16
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 7.7e-28. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# """
